# %%
import pickle
import random
from ase import Atoms, Atom
from ase.visualize import view
from ase.constraints import dict2constraint
from ase.calculators.singlepoint import SinglePointCalculator

# %%
data = pickle.load(open('Surface_Energy_data.pkl','rb'))
docs = data['docs']

# %%
# The 'intercept' value is extrapolated surface energy
# In addition, we used 'initial configuration' for tha cgcnn input
docs[0]
# Out:
# {'mongo_id': ObjectId('5c0a78c1871ca7c005fcf28d'),
#  'mpid': 'mp-580357',
#  'formula': 'Cu6Pd2',
#  'miller': [1, 0, 0],
#  'intercept': 0.11824409146003978,
#  'intercept_uncertainty': 0.009322162361717491,
#  'initial_configuration': {'atoms': {'atoms': [{'symbol': 'Cu',
#      'position': [1.82884281, 1.82884281, 13.716321075],
#      'tag': 0,
#      'index': 0,
#      'charge': 0.0,
#      'momentum': [0.0, 0.0, 0.0],
#      'magmom': 0.0},
#     {'symbol': 'Cu',
#      'position': [1.82884281, 0.0, 11.887478265],
#      'tag': 0,
#      'index': 1,
#      'charge': 0.0,
#      'momentum': [0.0, 0.0, 0.0],
#      'magmom': 0.0},
#     {'symbol': 'Cu',
#      'position': [0.0, 1.82884281, 11.887478265],
#      'tag': 0,
#      'index': 2,
#      'charge': 0.0,
#      'momentum': [0.0, 0.0, 0.0],
#      'magmom': 0.0},
#     {'symbol': 'Pd',
#      'position': [0.0, 0.0, 13.716321075],
#      'tag': 0,
#      'index': 3,
#      'charge': 0.0,
#      'momentum': [0.0, 0.0, 0.0],
#      'magmom': 0.0},
#     {'symbol': 'Cu',
#      'position': [1.82884281, 1.82884281, 17.374006695000002],
#      'tag': 0,
#      'index': 4,
#      'charge': 0.0,
#      'momentum': [0.0, 0.0, 0.0],
#      'magmom': 0.0},
#     {'symbol': 'Cu',
#      'position': [1.82884281, 0.0, 15.545163885000001],
#      'tag': 0,
#      'index': 5,
#      'charge': 0.0,
#      'momentum': [0.0, 0.0, 0.0],
#      'magmom': 0.0},
#     {'symbol': 'Cu',
#      'position': [0.0, 1.82884281, 15.545163885000001],
#      'tag': 0,
#      'index': 6,
#      'charge': 0.0,
#      'momentum': [0.0, 0.0, 0.0],
#      'magmom': 0.0},
#     {'symbol': 'Pd',
#      'position': [0.0, 0.0, 17.374006695000002],
#      'tag': 0,
#      'index': 7,
#      'charge': 0.0,
#      'momentum': [0.0, 0.0, 0.0],
#      'magmom': 0.0}],
#    'cell': [[3.65768562, 0.0, 0.0],
#     [0.0, 3.65768562, 0.0],
#     [0.0, 0.0, 29.26148496]],
#    'pbc': [True, True, True],
#    'info': {},
#    'constraints': [{'name': 'FixAtoms', 'kwargs': {'indices': []}}],
#    'natoms': 8,
#    'mass': 594.116,
#    'chemical_symbols': ['Cu', 'Pd'],
#    'symbol_counts': {'Cu': 6, 'Pd': 2},
#    'spacegroup': 'P4mm (99)',
#    'volume': 391.4795781935592},
#   'calc': {'calculator': {'module': 'ase.calculators.singlepoint',
#     'class': 'SinglePointCalculator'}},
#   'results': {'energy': -35.56312606,
#    'forces': [[-5.03e-06, 9.6e-07, -0.16367655],
#     [-3.79e-06, -1.15e-06, 0.31752286],
#     [2.21e-06, 2.76e-06, 0.31756179],
#     [1.301e-05, -2.51e-06, -0.43423908],
#     [4.4e-06, 9.7e-07, -0.39193362],
#     [1.99e-06, 2.76e-06, 0.22372414],
#     [-1.33e-06, 2.77e-06, 0.22375952],
#     [-1.146e-05, -6.55e-06, -0.09271906]],
#    'fmax': 0.43423908},
#   'user': 'zulissi',
#   'ctime': datetime.datetime(2018, 12, 7, 13, 5, 47, 322000),
#   'mtime': datetime.datetime(2018, 12, 7, 13, 5, 47, 322000)},
#  'FW_info': {'8': 243787, '12': 243788, '16': 243789, 'bulk': 239822},
#  'max_surface_movement': [0.10492992937765082,
#   0.08983082026458349,
#   0.08944102070199748],
#  'atoms': {'atoms': [{'symbol': 'Cu',
#     'position': [1.8288427002694314, 1.82884281, 13.7169074751586],
#     'tag': 0,
#     'index': 0,
#     'charge': 0.0,
#     'momentum': [0.0, 0.0, 0.0],
#     'magmom': 0.0},
#    {'symbol': 'Cu',
#     'position': [1.8288428465768565, 0.0, 11.94739905605654],
#     'tag': 0,
#     'index': 1,
#     'charge': 0.0,
#     'momentum': [0.0, 0.0, 0.0],
#     'magmom': 0.0},
#    {'symbol': 'Cu',
#     'position': [2.194611372e-07, 1.82884281, 11.94739934867139],
#     'tag': 0,
#     'index': 2,
#     'charge': 0.0,
#     'momentum': [0.0, 0.0, 0.0],
#     'magmom': 0.0},
#    {'symbol': 'Pd',
#     'position': [-3.65768562e-08, 1.097305686e-07, 13.708754932833893],
#     'tag': 0,
#     'index': 3,
#     'charge': 0.0,
#     'momentum': [0.0, 0.0, 0.0],
#     'magmom': 0.0},
#    {'symbol': 'Cu',
#     'position': [1.828842992884281, 1.8288428831537125, 17.269076765622536],
#     'tag': 0,
#     'index': 4,
#     'charge': 0.0,
#     'momentum': [0.0, 0.0, 0.0],
#     'magmom': 0.0},
#    {'symbol': 'Cu',
#     'position': [1.828842992884281, -1.097305686e-07, 15.547822876138314],
#     'tag': 0,
#     'index': 5,
#     'charge': 0.0,
#     'momentum': [0.0, 0.0, 0.0],
#     'magmom': 0.0},
#    {'symbol': 'Cu',
#     'position': [-1.82884281e-07, 1.8288428831537125, 15.547823168753165],
#     'tag': 0,
#     'index': 6,
#     'charge': 0.0,
#     'momentum': [0.0, 0.0, 0.0],
#     'magmom': 0.0},
#    {'symbol': 'Pd',
#     'position': [-2.926148496e-07, -1.097305686e-07, 17.360756509380412],
#     'tag': 0,
#     'index': 7,
#     'charge': 0.0,
#     'momentum': [0.0, 0.0, 0.0],
#     'magmom': 0.0}],
#   'cell': [[3.65768562, 0.0, 0.0],
#    [0.0, 3.65768562, 0.0],
#    [0.0, 0.0, 29.26148496]],
#   'pbc': [True, True, True],
#   'info': {},
#   'constraints': [{'name': 'FixAtoms', 'kwargs': {'indices': []}}],
#   'natoms': 8,
#   'mass': 594.116,
#   'chemical_symbols': ['Cu', 'Pd'],
#   'symbol_counts': {'Cu': 6, 'Pd': 2},
#   'spacegroup': 'P4mm (99)',
#   'volume': 391.4795781935592},
#  'results': {'energy': -35.60775786,
#   'forces': [[-2.8e-07, 9.6e-07, 0.00021662],
#    [-6.4e-07, 2.2e-07, 0.00677044],
#    [-1.2e-06, 8.4e-07, 0.00676912],
#    [5.51e-06, -3.13e-06, 0.01484023],
#    [-3.67e-06, -7.1e-07, -0.00565161],
#    [-4.23e-06, 1.14e-06, -0.01611992],
#    [1.92e-06, -2.4e-07, -0.01612177],
#    [2.6e-06, 9.2e-07, 0.0092969]],
#   'fmax': 0.01612177}}
