# %% [markdown]
# cleavage_energy: with a unit of eV/$angstrom^2$ <br>
# thinnest_structure: atoms object of the thinnest slab used in linear extrapolation method <br>
# thinnest_structure['initial_configuration']: cgcnn input

# %%
import pickle
docs = pickle.load(open('intermetallics_cleavage_energy_data.pkl','rb'))

# %%
docs[0]
# Out:
# {'mongo_id': ObjectId('5cded81b24a7b4f015739b4b'),
#  'mpid': 'mp-2695',
#  'miller': [0, 1, 1],
#  'shift': 0.044,
#  'thinnest_structure': {'_id': ObjectId('5c7493a87d9725e663a55134'),
#   'atoms': {'atoms': [{'symbol': 'Sb',
#      'position': [1.608148095, 1.9591096563150134, 21.086756363725648],
#      'tag': 0,
#      'index': 0,
#      'charge': 0.0,
#      'momentum': [0.0, 0.0, 0.0],
#      'magmom': 0.0},
#     {'symbol': 'Sb',
#      'position': [1.608148095, 6.470188050198775, 17.126987710706338],
#      'tag': 0,
#      'index': 1,
#      'charge': 0.0,
#      'momentum': [0.0, 0.0, 0.0],
#      'magmom': 0.0},
#     {'symbol': 'Sb',
#      'position': [1.608148127162962, 6.840118545036731, 14.28553893121036],
#      'tag': 0,
#      'index': 2,
#      'charge': 0.0,
#      'momentum': [0.0, 0.0, 0.0],
#      'magmom': 0.0},
#     {'symbol': 'Sb',
#      'position': [1.608148095, 2.3964931202039583, 18.212463518329557],
#      'tag': 0,
#      'index': 3,
# ...
